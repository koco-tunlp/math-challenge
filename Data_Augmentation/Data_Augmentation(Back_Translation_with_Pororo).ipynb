# %%
# !pip install pororo
# Out:
# ...
#      |████████████████████████████████| 256 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 65.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 51.7 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 42.4 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 50.5 MB/s
# ...
#      |████████████████████████████████| 468 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 22.1 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 58.5 MB/s
# ...
#      |████████████████████████████████| 748.8 MB 18 kB/s
# ...
#      |████████████████████████████████| 79 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 90 kB 11.0 MB/s
# ...
#      |████████████████████████████████| 147 kB 73.2 MB/s
# ...
#      |████████████████████████████████| 749 kB 60.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 54.3 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 67.9 MB/s
# ...

# %%
from pororo import Pororo

Pororo.available_tasks()
# Out:
# "Available tasks are ['mrc', 'rc', 'qa', 'question_answering', 'machine_reading_comprehension', 'reading_comprehension', 'sentiment', 'sentiment_analysis', 'nli', 'natural_language_inference', 'inference', 'fill', 'fill_in_blank', 'fib', 'para', 'pi', 'cse', 'contextual_subword_embedding', 'similarity', 'sts', 'semantic_textual_similarity', 'sentence_similarity', 'sentvec', 'sentence_embedding', 'sentence_vector', 'se', 'inflection', 'morphological_inflection', 'g2p', 'grapheme_to_phoneme', 'grapheme_to_phoneme_conversion', 'w2v', 'wordvec', 'word2vec', 'word_vector', 'word_embedding', 'tokenize', 'tokenise', 'tokenization', 'tokenisation', 'tok', 'segmentation', 'seg', 'mt', 'machine_translation', 'translation', 'pos', 'tag', 'pos_tagging', 'tagging', 'const', 'constituency', 'constituency_parsing', 'cp', 'pg', 'collocation', 'collocate', 'col', 'word_translation', 'wt', 'summarization', 'summarisation', 'text_summarization', 'text_summarisation', 'summary', 'gec', 'review', 'review
# ...

# %%
mt = Pororo(task='translation', lang='multi')

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("/content/drive/MyDrive/Project/AIFFEL/Aiffelthon/data/train.csv")
train.head()
# Out:
#    class                                            problem  \
# 0      8  한 변의 길이가 24cm인 정육각형과 둘레가 같은 정팔각형이 있습니다. 이 정팔각형...
# 1      1  윤아는 부추전을 똑같이 8조각으로 나누어 한 조각을 먹었습니다. 윤미는 같은 크기의...
# 2      8  화단 주변에 한 변이 12m인 정팔각형 모양의 울타리를 두른다면, 울타리는 모두 몇...
# 3      3  6장의 숫자 카드 0, 9, 8, 7, 2, 1가 있습니다. 이를, 한 번씩 사용하...
# 4      1                               0.26 x 0.8을 계산해 주세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# 3  from itertools import permutations\n\na = ['0'...  987210
# 4  a = 0.26\nb = 0.8\ny = a * b\nprint("{:.2f}".f...    0.21

# %%
mt(train['problem'][0], src='ko', tgt='en')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [Korean Sentence Splitter]: Initializing Pynori...
# 'There is a square and square-shaped shape with a 24cm length. Find out how many centimeters of this square one is.'

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ko', tgt='en')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8  There is a square and square-shaped shape with...
# 1      1  Yoon-ah shared the boccoli with eight pieces i...
# 2      8  How many meters of the fence would be if you p...
# 3      3  There are six digital cards 0, 9, 8, 7, 2, 1. ...
# 4      1                              Calculate 0.26 x 0.8.
# 5      7  The distance from Hyunsu's house to beauty sal...
# 6      6  It was divided into nine by mistake in which n...
# 7      1  The group of Na-eun and Do-jin shared the subw...
# 8      7  The length of the color pencil that Su-jeong h...
# 9      1  Find out how many wheels are for all 12 head-t...
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ko', tgt='en')
    train['problem'][i] = mt(train['problem'][i], src='en', tgt='ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8    스케일과 스케일 모양으로 길이가 24㎝에 달한다. 그 스케일의 많은 센티미터를 찾아라
# 1      1  연아, 삼웨이에는 8개의 작품이 있다. 유미가 16피스에서 추진의 동일한 크기를 했...
# 2      8    자금을 받은 세상의 남자들이 몇 명인지 12미터 떨어진 화단으로 규모를 두고 있는가?
# 3      3  디지털 코드 0, 9, 8, 7, 2, 1이다. 이들과 우리는 가장 긴 누비어의 가...
# 4      1                                   0.26 x 0.8을 부르세요
# 5      7  현수의 집이 4/5㎞, 1/3㎞, 0.9㎞에 걸쳐 미용실, 병원, 레퍼토리로 이뤄질...
# 6      6  애초에는 실수였고, 그 다음에는 틀렸다 교육과정이라고 하면 얼마나 많이 부르느냐에 ...
# 7      1  내은과 도진의 샤일 그래프가 그려졌다. 15인승 컨버터와 도진의 11인승 융합은 별...
# 8      7              협업 기간은 6.1㎝로 볼펜 길이가 6.5㎝다. 이게 무슨 일이야?
# 9      1                      총 12대 히드 바이크에 사람이 무엇인지 찾아보세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
train = pd.read_csv("/content/drive/MyDrive/Project/AIFFEL/Aiffelthon/data/train.csv")
train.head()
# Out:
#    class                                            problem  \
# 0      8  한 변의 길이가 24cm인 정육각형과 둘레가 같은 정팔각형이 있습니다. 이 정팔각형...
# 1      1  윤아는 부추전을 똑같이 8조각으로 나누어 한 조각을 먹었습니다. 윤미는 같은 크기의...
# 2      8  화단 주변에 한 변이 12m인 정팔각형 모양의 울타리를 두른다면, 울타리는 모두 몇...
# 3      3  6장의 숫자 카드 0, 9, 8, 7, 2, 1가 있습니다. 이를, 한 번씩 사용하...
# 4      1                               0.26 x 0.8을 계산해 주세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# 3  from itertools import permutations\n\na = ['0'...  987210
# 4  a = 0.26\nb = 0.8\ny = a * b\nprint("{:.2f}".f...    0.21

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ko', tgt='ja')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8  一辺の長さが24センチの静六角形と周囲が同じ正八角形があります。 この八角形の一辺の長さは何...
# 1      1  ユンアはブチュージョンを同じように八切れに分けて一切れを食べました。 ユンミは同じサイズのブ...
# 2      8       画壇の周辺に一辺が12メートルの正八角形の垣根を巻いたら、垣根は全部何メールでしょうか。
# 3      3  6枚の数字カード0、9、8、7、2、1があります。 これを、一度使って、一番大きな六番目の数...
# 4      1                                   0.26x0.8をお願いします。
# 5      7  ヒョンスの家から美容院、病院、デパートまでの距離は、それぞれ4/5キロ、1/3キロ、0.9キ...
# 6      6  いくつかの数を3に分けなければならないことを間違えて9に分けたら分け前が9になりました。 正...
# 7      1  よい人集まりとドジンの集まりが電車に乗り換えました。 ナウンの集まり8人は15人乗りの間に乗...
# 8      7  水晶の持っている色鉛筆の長さは6.1センチ、ボールペンの長さが6.5センチです。 どちらが長...
# 9      1                          頭髪自転車12台の車輪は全部何個か探してみなさい。
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ja', tgt='ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8  일변의 길이가 24센티미터의 정육각형과 주위가 같은 정팔각형이 있습니다. 이 팔각형...
# 1      1  윤아는 부추전을 같이 여덟 조각으로 나누어 한 조각을 먹었습니다. 윤미는 같은 사이...
# 2      8  화단 주변에 일변이 12미터의 정팔각형의 울타리를 감았다면, 담장은 전부 몇 메일입니까?
# 3      3  6장의 숫자카드 0, 9, 8, 7, 2, 1이 있습니다. 이것을 한번 사용해서 가...
# 4      1                                   0.26x0.8을 부탁합니다.
# 5      7  현수의 집에서 미용실, 병원, 백화점까지의 거리는 각각 4/5킬로미터, 1/3킬로그...
# 6      6  몇 개의 수를 3으로 나누어야 하는 것을 잘못해서 9로 나눈다면 몫이 9이 되었습니...
# 7      1  좋은 사람들과 도진의 모임이 전철로 갈아탔습니다. 나운의 모임 8명은 15명 승차 ...
# 8      7  수정이 가지고 있는 색연필 길이는 6.1센티미터, 볼펜 길이가 6.5센치입니다. 어...
# 9      1                  머리카락 자전거 12대의 차륜은 모두 몇 개인지 찾아보세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
train = pd.read_csv("/content/drive/MyDrive/Project/AIFFEL/Aiffelthon/data/train.csv")
train.head()
# Out:
#    class                                            problem  \
# 0      8  한 변의 길이가 24cm인 정육각형과 둘레가 같은 정팔각형이 있습니다. 이 정팔각형...
# 1      1  윤아는 부추전을 똑같이 8조각으로 나누어 한 조각을 먹었습니다. 윤미는 같은 크기의...
# 2      8  화단 주변에 한 변이 12m인 정팔각형 모양의 울타리를 두른다면, 울타리는 모두 몇...
# 3      3  6장의 숫자 카드 0, 9, 8, 7, 2, 1가 있습니다. 이를, 한 번씩 사용하...
# 4      1                               0.26 x 0.8을 계산해 주세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# 3  from itertools import permutations\n\na = ['0'...  987210
# 4  a = 0.26\nb = 0.8\ny = a * b\nprint("{:.2f}".f...    0.21

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ko', tgt='zh')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8             有一个方向有24cm长的直角形和周围有相同的八角形 找到这个四角形的一个尺寸
# 1      1  Yuna分成了八块的副作用 吃了一块 Yunmi把同一个大小的推进器分成了十六块 Yunmi...
# 2      8                       如果围绕着四角形的围墙 有一个十二m的围栏 围墙会有多远
# 3      3                    六张数字卡 0,9,8,7,2,1 用这个来创造最大的六个位置
# 4      1                                       计算一下0.26x0.8
# 5      7      现在的房子 美容院 医院 百货公司都有四分五公里 三公里 零九公里 我们最靠近的地方是哪里
# 6      6                我们分成了九分之一的错误分成三分之一 如果你正确计算 你就得找到多少钱
# 7      1   好的集会和多金的集会 分开了火车 八个好人上了十五人车 六个都在十一人车厢 寻找更广阔的集合人口
# 8      7         Sujen的色鉛筆長度是6.1cm Bolpen長度是六.5cm 你们还有什么更长的
# 9      1                                            看看有多少轮子
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='zh', tgt='ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8  24㎝ 길이의 직각형과 같은 팔각형을 가지고 있는 방향으로 이 사각형의 한 척을 찾았어요
# 1      1  유나는 여덟 개의 부작용으로 나뉘어 한 개를 먹었고 윤미는 같은 작은 추진기를 십육...
# 2      8                    사각형 벽을 둘러싸고 있다면 12m의 울타리가 있을 거야
# 3      3  여섯 개의 숫자 카드 0,9,8,7,2,1을 이용해서 가장 큰 6개의 위치를 만들어...
# 4      1                                    0.26x0.8을 계산하세요
# 5      7  지금의 집, 미용실, 병원, 백화점 모두 4분의 5마일, 3파일, 0분의 9마일로 ...
# 6      6     우리가 9분의 1의 1을 하나로 나누어 계산하면 얼마나 많은 돈을 찾을 수 있을까?
# 7      1  좋은 모임과 도킨의 모임이 열차를 분리하고 좋은 사람 8명이 15명이나 차에 타고 ...
# 8      7        수잔의 색연필 길이는 6.1cm이고 볼펜 길이가 6.5cm로 더 긴 게 뭐야?
# 9      1                                   타이어가 얼마나 되는지 보세요
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %% [markdown]
# transformer.large + ko->en->ja->ko

# %%
from pororo import Pororo
mt = Pororo(task="translation", lang="multi", model="transformer.large.multi.mtpg")
# fast_mt = Pororo(task="translation", lang="multi", model="transformer.large.multi.fast.mtpg")

# %%
train = pd.read_csv("/content/drive/MyDrive/Project/AIFFEL/Aiffelthon/data/train.csv")
train.head()
# Out:
#    class                                            problem  \
# 0      8  한 변의 길이가 24cm인 정육각형과 둘레가 같은 정팔각형이 있습니다. 이 정팔각형...
# 1      1  윤아는 부추전을 똑같이 8조각으로 나누어 한 조각을 먹었습니다. 윤미는 같은 크기의...
# 2      8  화단 주변에 한 변이 12m인 정팔각형 모양의 울타리를 두른다면, 울타리는 모두 몇...
# 3      3  6장의 숫자 카드 0, 9, 8, 7, 2, 1가 있습니다. 이를, 한 번씩 사용하...
# 4      1                               0.26 x 0.8을 계산해 주세요.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# 3  from itertools import permutations\n\na = ['0'...  987210
# 4  a = 0.26\nb = 0.8\ny = a * b\nprint("{:.2f}".f...    0.21

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ko', tgt='en')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8  There is a square and square-shaped shape with...
# 1      1  Yoon-ah shared the boccoli with eight pieces i...
# 2      8  How many meters of the fence would be if you p...
# 3      3  There are six digital cards 0, 9, 8, 7, 2, 1. ...
# 4      1                              Calculate 0.26 x 0.8.
# 5      7  The distance from Hyunsu's house to beauty sal...
# 6      6  It was divided into nine by mistake in which n...
# 7      1  The group of Na-eun and Do-jin shared the subw...
# 8      7  The length of the color pencil that Su-jeong h...
# 9      1  Find out how many wheels are for all 12 head-t...
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='en', tgt='ja')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8           四センチメートルの広いスタイルがある。 この広場の数センチメートルを調べてくれ。
# 1      1  ユンアは同じように ボコリーを共有した。 ユンミはプロモーションの大きさを 16部に分けた。...
# 2      8                どのくらいのフェンスが 花のベッドに囲まれたら それは十二メートルだ？
# 3      3       デジタルカード0 9 8 7 2 1。 これを使って一度使って 最大の6人の座席を作る。
# 4      1                                      0.26 x0.8を計算。
# 5      7  ヒョンスの家から 美容院と病院とデパートの距離は 4.5㎞, 1/3㎞, 0.9㎞。 賢秀の...
# 6      6     間違いで九つに分かれた 数字を三つに分けて 九つになった。 正確に計算すれば いくらですか。
# 7      1  ナウンとドジンのグループは 地下鉄を共有した。 ナウンの八人は 15セーターの部屋にいた ド...
# 8      7  スージョンが持っている色のペンの長さは 6.1センチメートル ボールペンは6.5センチ。 ど...
# 9      1                                 バイクがどれくらいあるか調べてくれ。
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...

# %%
for i in range(10):
    train['problem'][i] = mt(train['problem'][i], src='ja', tgt='ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.head(10)
# Out:
#    class                                            problem  \
# 0      8            4센티미터 넓은 스타일이 있어. 이 광장의 몇 센티미터를 조사해 주게.
# 1      1  윤아는 마찬가지로 보컬리를 공유했다. 윤미는 프로모션의 크기를 16부로 나누었다. ...
# 2      8                    어느 정도 울타리가 꽃 침대에 둘러싸여 있으면 12미터?
# 3      3  디지털 카드 0.9.8.7.2.1. 이것을 사용해서 한 번 사용하여 최대 6명의 좌...
# 4      1                                 0.26x0.8을 계산해 주세요.
# 5      7  현수의 집에서 미용실과 병원과 백화점의 거리는 4.5㎞, 1/3㎞, 0.9㎞. 현수...
# 6      6   실수로 9개로 나뉜 숫자를 세 개로 쪼개서 9개가 되었다. 정확히 계산하면 얼마입니까?
# 7      1  나운과 도진 그룹은 지하철을 공유했다. 나운의 여덟 사람은 15센터 방에 있었고 도...
# 8      7  수전이 가지고 있는 색깔의 펜의 길이는 6.1센티미터, 볼펜은 6.5센치. 어느 쪽...
# 9      1                              오토바이가 얼마나 되는지 알아봐 주게.
#
#                                                 code  answer
# 0     a = 24\nb = 6\nc = 8\ny = a * b // c\nprint(y)      18
# 1                a = 8\nb = 16\ny = b // a\nprint(y)       2
# 2                 a = 12\nb = 8\ny = a * b\nprint(y)      96
# ...
