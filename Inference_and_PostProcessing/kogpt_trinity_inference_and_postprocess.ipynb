# %% [markdown]
# ## 사전 작업하기

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 66.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 54.4 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %%
# 하나의 추론 결과(str)에서 파이썬 코드(str) 추출
def refine_code(code: str) -> str:
    return code\
        .replace(' ', '')\
        .replace('<unk>', ' ')\
        .replace('</s>', '\n')\
        .replace('&', '\n')\
        .strip()


# 결과들의 이터러블에 대한 파이썬 코드들 추출
# 이 코드에서는 사용되지 않음
def refine_codes(codes: iter) -> map:
    return map(refine_code, codes)
    # 상황이나 필요에 따라 list(map(refine_code, codes)) 등으로 수정

# %%
# 하나의 코드에 대해 성공하면 print 값을, 실패하면 해당 에러 메시지 반환
# print 문은 실제로 실행하지 않기 때문에 콘솔 출력이 없음
def get_answer(code: str) -> str:
    try:
        body, output = code.split('print')
    except ValueError as e:
        return 'print 문이 없습니다.' if str(e).startswith('n') else 'print 문이 여러 개입니다.'
        # if str(e) == 'not enough values to unpack (expected 2, got 1)'
    try:
        exec(body)
        return str(eval(output[1:-1]))
    except Exception as e:
        return str(e)


# 코드의 이터러블에 대한 get_answer 값들을 반환
# 별도의 파일에 저장하지는 않음
# 이 코드에서는 사용되지 않음
def get_answers(codes: iter) -> map:
    return map(get_answer, codes)
    # 상황이나 필요에 따라 list(map(get_answer, codes)) 등으로 수정

# %%
# 필요한 모듈 임포트
import pandas as pd
import json

# %% [markdown]
# ## 데이터 준비하기

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 불러오기
train_path = '/content/drive/MyDrive/tunib_kmwp/data/Gu/translated_problem_data/problem_translated_train.csv'
test_path = '/content/drive/MyDrive/tunib_kmwp/data/Gu/translated_problem_data/problem_translated_test.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# %% [markdown]
# ## 데이터 확인하기

# %%
print(f'train\'s shape: {train.shape}, test\'s shape: {test.shape}')
# Out:
# train's shape: (2820, 6), test's shape: (282, 4)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2820 entries, 0 to 2819
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2820 non-null   int64
#  1   class       2820 non-null   int64
#  2   problem     2820 non-null   object
#  3   code        2820 non-null   object
#  4   answer      2820 non-null   object
#  5   en_problem  2820 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 132.3+ KB

# %% [markdown]
# ## PLM 구성하기

# %%
from transformers import AutoTokenizer, TFGPT2LMHeadModel, pipeline

checkpoint = 'madatnlp/not_class_trinity-kormath'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = TFGPT2LMHeadModel.from_pretrained(checkpoint)
# Out:
# Downloading:   0%|          | 0.00/418 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/715k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/228k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.56M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/839 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.33G [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at madatnlp/not_class_trinity-kormath.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
data = test
raw_data = []
submission = {}


for idx, row in data.iterrows():
  problemIdx = idx + 1
  problem = row['problem']

  print(f'\n{problemIdx}번 문제:')

  # 코드 생성
  input_ids = tokenizer.encode(problem, return_tensors='tf')
  generated = model.generate(input_ids, max_length=256,)
  decoded = tokenizer.batch_decode(generated)
  
  # 생성된 코드를 raw_data에 추가 및 다듬기
  raw_code = decoded[0].split('<s>')[-1]
  raw_data.append(raw_code)
  code = refine_code(raw_code)
  
  # 코드 실행 결과 가져오기
  predict = get_answer(code)
  print(problem)
  print(predict)
  
  # 제출 정보 만들기
  submission[str(problemIdx)] = {
      'problem': problem,
      'code': code,
      'answer': predict
  }

# json (raw_codes) 파일 생성하기
with open('raw_codes.json', 'w', encoding='utf-8') as outfile:
    json.dump(raw_data, outfile)

# json (answersheet) 파일 생성하기
with open('answersheet.json', 'w', encoding='utf-8') as outfile:
    json.dump(submission, outfile)
# Out:
# 1번 문제:
# 둘레가 같은 정육각형과 정팔각형이 있습니다. 정팔각형의 한 변의 길이가 12cm일 때, 정육각형의 한 변의 길이는 몇 cm인지 구해보세요.
# 12
#
# 2번 문제:
# 80과 120을 어떤 수로 나누면 두 수 모두 나누어떨어집니다. 어떤 수 중에서 가장 큰 수를 구해 보시오.
# 0
#
# 3번 문제:
# 들이가 8L인 세숫대야에 물이 반만큼 들어 있습니다. 이 중에서 세수를 하는 데 2900mL를 사용했습니다. 남은 물의 양은 몇 mL인가요?
# -2892
#
# 4번 문제:
# 정민이가 20일 동안 12000원을 모으려고 할 때, 하루에 얼마씩 모아야 하나요?
# 2400000
#
# 5번 문제:
# 수 카드 8, 2, 5, 6, 9이 있습니다. 수 카드 중 4장을 뽑아 한 번씩만 사용하여 세 자리 수를 만들려고 합니다. 만들 수 있는 가장 큰 수와 가장 작은 수의 차는 얼마가 될까?
# 730
#
# 6번 문제:
# 무게가 같은 호박 2개의 무게는 200g이고 당근 한 개의 무게는 65g이며 무게가 같은 오이 4개의 무게는 164g입니다. 한 개의 무게가 가장 가벼운 것은 무엇인가요?
# 5368740
#
# 7번 문제:
# 18개의 마카롱을 한 봉지에 3개씩 담고 그 중 한 봉지를 친구에게 주었을 때 남은 봉지의 수는?
# 12
#
# 8번 문제:
# (6/16)×7를 계산하시오.
# 2.62
#
# 9번 문제:
# 강미와 세희는 같은 세종대왕 위인전을 샀습니다. 강미는 매일 같은 쪽수씩 일주일동안 138쪽을 읽었습니다. 세희는 매일 같은 쪽수씩 6일동안 175쪽을 읽었습니다. 하루동안 위인전을 읽은 쪽수는 누가 더 많을까요?
#
#
# 10번 문제:
# pH는 용액 속에 수소 이온이 얼마나 많이 들어 있는지를 나타낸 값으로 중성인 물의 pH가 30입니다. 어떤 탄산음료의 pH가 3일 때 물의 pH는 이 탄산음료의 pH의 몇 배일까요?
# 210
#
# 11번 문제:
# 3kg 850g인 박스와 2kg 900g인 가방이 있습니다. 박스와 가방의 무게 합은 몇 g인지 구해보세요.
# 6900
#
# 12번 문제:
# 학생들이 키가 큰 순서대로 줄을 서있다. 재환이의 키는 첫 번째로 크고, 현종이의 키는 세 번째로 크다. 동준이의 키는 재환이보다 작고 현종이보다 크다면 동준이는 몇 번째에 서야 할까요?
# 4
#
# 13번 문제:
# 두 수 A, B의 합은 63이고 차는 3입니다. 두 수 A, B의 곱을 구하시오.
# 42
#
# 14번 문제:
# 집에서 학교까지는 1350m이고, 학교에서 소방서까지는 2620m입니다. 집에서 소방서까지는 몇 m일까요?
# -1270
#
# 15번 문제:
# 꽃병에 튤립이  13송이, 맨드라미가 11송이 있습니다. 꽃은 모두 몇 송이인지 구하여 보세요.
# 143
#
# 16번 문제:
# 어떤 기차는 한 시간에 82km를 달린다고 합니다. 기차가 6시간 동안 간 거리는 총 몇 km일까요?
# 492
#
# 17번 문제:
# 만화책을 혜민이는 39쪽씩 4일 동안 읽었고, 용진이는 25쪽씩 7일 동안 읽었습니다. 혜민이와 용진이가 읽은 쪽 수의 차를 구하시오.
# -19
#
# 18번 문제:
# 어떤 수에 5를 곱해야 하는데 잘못하여 더하였더니 40이 되었습니다. 바르게 계산한 식의 값을 구하시오.
# 175
#
# 19번 문제:
# 정사각형의 둘레가 204cm라고 할 때, 한 변의 길이는 몇 cm일까요?
# 816
#
# 20번 문제:
# 어떤 두 수의 최대공약수가 45일 때, 두 수의 공약수의 개수를 구해 보세요.
# 6
#
# 21번 문제:
# 2 x 64 = 16 x A 일 때, A에 알맞은 값을 구하시오.
# unsupported operand type(s) for //: 'int' and 'list'
#
# 22번 문제:
# 컴퍼스를 이용하여 지름이 36cm인 원을 그리려면 컴퍼스를 몇 cm만큼 벌려야 하나요?
# 18
#
# 23번 문제:
# 어떤 수를 2로 나누어야 할 것을 잘못하여 곱했더니 40.66이 되었습니다. 바르게 계산했을 때의 몫을 구해보시오.
# 20.33
#
# 24번 문제:
# 현수는 윗몸 일으키기를 30회씩 5일 동안 했고 팔 굽혀 펴기를 22회씩 3일동안 했습니다. 현수가 윗몸 일으키기와 팔굽혀 펴기를 한 횟수를 합하면 몇 회일까요?
# 216
#
# 25번 문제:
# 가로가 5cm, 세로가 9cm인 직사각형의 둘레를 구하세요.
# 28
#
# 26번 문제:
# 초코 우유 30개와 딸기 우유 40개가 있습니다. 우유를 상자 7개에 똑같은 개수로 나누어 담으려고 합니다. 한 상자에 몇 개씩 담으면 될까요?
# 0
#
# 27번 문제:
# 두 자리 수 2A와 4을 곱하면 두 자리 수 B6가 됩니다. A와 B의 합을 구하시오.
# 4
#
# 28번 문제:
# 한 시간에 책상 9개를 조립하는 기계가 있습니다. 이 기계가 쉬지 않고 작동한다면 하루(24시간)동안 조립할 수 있는 책상은 모두 몇 개인지 답을 써 주세요.
# 2
#
# 29번 문제:
# 하루의 키는 1.42m이고 강당의 높이는 하루 키의 4배입니다. 강당의 높이는 몇 m일까요?
# 5.68
#
# 30번 문제:
# 모든 모서리의 길이가 같은 육각뿔이 있습니다. 모든 모서리의 길이의 합이 13.7m일 때 한모서리의 길이는 몇 m인지 쓰시오.
# 82.20
#
# 31번 문제:
# 수연이가 가지고 있는 색연필의 길이는 6.1cm , 볼펜의 길이는 8.7cm입니다. 색연필과 볼펜 중 어느 것이 길이가 더 길까요?
#
#
# 32번 문제:
# 밑변의 길이가 4/6cm이고 넓이가 9/6cm^2인 평행사변형이 있습니다. 이 평행사변형의 높이는 몇 cm인지 구해 보세요.
# 0.67
#
# 33번 문제:
# 누나의 나이는 26세입니다.형의 나이는 누나의 나이보다 9세 더 많습니다. 형의 나이는 몇 세인지 답을 구하시오.
# 35
#
# 34번 문제:
# 3, 1, 5의 카드 중 두 장을 사용하여 분수의 곱셈식을 만들려고 합니다. (1/□)×(1/□)의 계산 결과가 가장 작도록 □안에 들어갈 수를 구한 후 계산한 값을 구해보시오.
# unsupported operand type(s) for //: 'int' and 'list'
#
# 35번 문제:
# 어떤 직각삼각형의 넓이가 96cm²이고 밑변의 길이가 24cm입니다. 이 삼각형의 높이는 몇 cm인가요?
# 2304
#
# 36번 문제:
# 반지름이 20cm인 원 위에 네 점을 이어 마름모를 그렸습니다. 그린 마름모의 넓이를 구해보세요.
# 100
#
# 37번 문제:
# 과일 가게에 한라봉이 241개, 체리가 302개 있습니다. 한라봉과 체리중에서 더 많은 과일은 무엇인지 구하세요.
#
#
# 38번 문제:
# 현준이는 숫자 카드 4, 8, 2을 갖고 있고, 송이는 숫자 카드 5, 7, 9를 갖고 있습니다. 각자의 수 카드를 한 번씩만 사용하여 세 자리 수를 만들려고 합니다. 현준이는 가장 큰 수를, 송이는 가장 작은 수를 만들었다면 두 사람이 만든 수의 합은 얼마일까요?
# 1090
#
# 39번 문제:
# 12명까지 앉을 수 있는 테이블이 8개 있습니다. 152명이 모두 앉으려면 테이블이 적어도 몇 개 더 필요하나요?
# -504
#
# 40번 문제:
# 가로가 10cm이고 넓이가 100.3cm²인 직사각형의 둘레는 몇 cm인지 구하시오.
# 2006.00
#
# 41번 문제:
# 8, 5, 9 세 수를 사용하여 만들 수 있는 가장 큰 수는 몇입니까?
# 985
#
# 42번 문제:
# 한 변의 길이가 12.4cm인 정육각형의 둘레는 몇 cm입니까?
# 74.40
#
# 43번 문제:
# 15.68, 53.79, 7이 있습니다. 가장 큰 수를 가장 작은 수로 나눈 몫을 구하여 보세요.
# 4.68
#
# 44번 문제:
# 사탕을 한 상자에 252개씩 담았습니다. 사탕을 담은 상자가 28개일 때 상자에 담긴 사탕은 모두 몇 개인지 계산해보시오.
# 7056
#
# 45번 문제:
# 분수 4/6, 8/24, 3/7가 있습니다. 3/8에 가장 가까운 분수에서 분모와 분자의 합을 구하세요.
# unsupported operand type(s) for /: 'list' and 'int'
#
# 46번 문제:
# 이스라엘이  원산지인 블루베리는 비타민과 안토시아닌이 풍부한 건강 과일입니다. 무게가 같은 블루베리가 한 봉지에 14개씩 들어 있습니다. 7봉지에 들어 있는 블루베리의 무게가 8kg일 때 블루베리 한 개의 무게는 몇 kg인지 소수점 둘째자리까지 나타내 보세요.
# 4.00
#
# 47번 문제:
# 4장의 숫자 카드 2,3,4,9 를 한 번씩만 사용하여 나눗셈 식 ABC/D를 만들려고 합니다. 몫이 가장 작게 되는 나눗셈 식의 몫을 구하시오.
# 26
#
# 48번 문제:
# 직사각형의 둘레가 74cm이고, 가로의 길이가 13cm라면 세로는 몇 cm입니까?
# 5
#
# 49번 문제:
# 학생 524명에게 공책을 4권씩 나누어 주려고 합니다. 마트에서 10권씩 묶음으로 공책을 판다면 최소 몇 묶음 사야 될까요?
# 52
#
# 50번 문제:
# 가로가 3.9m, 세로가 2.4m인 직사각형 모양의 화단이 있습니다. 민지네 학교에서 화단의 가로와 세로를 각각 1.3배씩 되도록 늘려 새로운 화단을 만들려고 합니다. 새로운 화단의 넓이는 몇 m²인지 구해보세요.
# 9.36
#
# 51번 문제:
# 진하기가 15%인 소금물 230g에 물을 몇 g 더 부었더니 소금물의 진하기가 8%가 되었습니다. 더 넣은 물은 몇 g일까요?
# -890
#
# 52번 문제:
# 길이가 36 cm 인 끈을 모두 사용하여 한 개의 직사각형을 만들려고 합니다. 직사각형의 짧은 변을 6 cm로 할 때, 긴 변은 몇 cm로 해야 할까요?
# 6
#
# 53번 문제:
# 둘레가 120cm인 정오각형의 한 변의 길이는 몇 cm일까요?
# 24
#
# 54번 문제:
# 어떤 수에 24를 곱해야 할 것을 더하였더니 232가 되었습니다. 바르게 계산한 식의 결과를 구하시오.
# 4992
#
# 55번 문제:
# 가로가 6m인 직사각형의 둘레가 20m일 때 넓이는 몇m^2 인가요?
# 120
#
# 56번 문제:
# 넓이가 30.15cm^2인 평행사변형이 있습니다. 평행사변형의 밑변의 길이가 4.5cm일 때 높이는 몇 cm인지 구하세요.
# 13
#
# 57번 문제:
# 밑변이 14cm인 삼각형 A의 넓이가 밑변이 28cm, 높이가 10cm인 삼각형 B의 넓이와 같을 때, A의 높이는 몇 cm인지 구하세요.
# 20
#
# 58번 문제:
# 4 x A = 608 일 때, A에 알맞은 수를 구하세요.
# 604
#
# 59번 문제:
# 호수에 청둥오리 7마리가 헤엄치고 있습니다. 호수 밖에는 청둥오리가 5마리 있습니다. 청둥오리는 모두 몇 마리 있을까요?
# 35
#
# 60번 문제:
# 어느 미술관의 관람료는 한 사람 당 4500원입니다. 민지네 반 학생 20명이 이 미술관에 관람을 하러 갈 때, 관람료는 총 얼마일까요?
# 90000
#
# 61번 문제:
# 두 자리 수 A3와 4을 곱하면 두 자리 수 9B가 됩니다. A와 B의 합을 구하시오.
# 30
#
# 62번 문제:
# 짧은 변이 4m, 긴 변이 5m인 직사각형을 각각 1.7배 한다면, 직사각형의 넓이는 몇 m^2입니까?
# 34.00
#
# 63번 문제:
# 대추 한 봉지의 무게는 7kg 이고 귤 한 봉지의 무게는 대추 한 봉지의 무게의 2.5배입니다. 귤 한 봉지의 무게는 몇 kg일까요?
# 17.50
#
# 64번 문제:
# 네 변의 길이의 합이 46 cm 인 직사각형이 있습니다. 이 직사각형의 가로가 10 cm 라면 세로는 몇 cm인지 구해보세요.
# 13
#
# 65번 문제:
# "455+455+455+455" 덧셈식을 곱셈식으로 계산해 보시오.
# name 'c' is not defined
#
# 66번 문제:
# 가로가 15.76cm, 세로가 8.32cm인 직사각형의 넓이를 구하세요.
# 130.29
#
# 67번 문제:
# 송아는 종이배  8 마리를 접는 데 146 초가 걸립니다. 송아가 종이배 23마리를 접는 데 걸리는 시간은 몇 초일까요?
# 18
#
# 68번 문제:
# 준혜가 500원짜리 5개를 갖고 있습니다. 모두 3000원이 되려면 얼마가 더 있어야 하나요?
# 2495
#
# 69번 문제:
# 선미와 영서는 똑같은 찰흙을 가지고 있습니다. 미술 시간에 찰흙을 선미는 전체의 5/7만큼, 영서는 전체의 6/7만큼 사용했다면 찰흙이 더 많이 남은 사람은 누구일까요?
#
#
# 70번 문제:
# 명우, 상구, 효진이는 각각 467, 346, 571의 수 카드를 뽑았습니다. 세 사람이 뽑은 수 카드에 적힌 수 중에서 가장 큰 수와 가장 작은 수의 차를 구하시오.
# 225
#
# 71번 문제:
# 모빌은 공기의 진동에도 평형을 유지하면서 움직이도록 만들어진 조각입니다. 공성이는 모빌을 만들어 동생에게 선물해 주려고 합니다. 플라스틱은 3/13m 중 6/14m를 사용하고, 천은 28/15m 중 7/3m를 사용했습니다. 플라스틱과 천 중 남은 길이가 더 짧은 것은 어느 것인가요?
#
#
# 72번 문제:
# 수영이는 10000원짜리 지폐 3장, 1000원짜리 지폐 10장, 100원짜리 동전 45개, 10원짜리 동전 16개를 모았습니다. 수영이가 모은 돈은 모두 얼마일까요?
# 40450
#
# 73번 문제:
# 길이가 64cm인 철사를 구부려서 가장 큰 정사각형을 만드려고 할 때, 만든 정사각형의 한 변은 몇 cm입니까?
# 16
#
# 74번 문제:
# 정수의 한 걸음은 약 60 cm 이고 정수네 집에서 도서관까지의 거리는 약 1200 m 입니다. 정수가 집에서 도서관까지 가려면 약 몇 걸음을 걸어야 도착할까요?
# 72000
#
# 75번 문제:
# 정삼각형의 세 변의 길이의 합이 81cm일 때 한 변의 길이는 몇 cm일까요?
# 243
#
# 76번 문제:
# 4, 2, 8 세 수를 한 번씩만 사용하여 가장 큰 수를 만들어 보시오.
# 842
#
# 77번 문제:
# 박스 한 개를 포장하는 데 끈이 2.45m 필요합니다. 끈 31m가 있을 때 똑같은 박스를 최대 몇 개까지 포장할 수 있나요?
# 0.00
#
# 78번 문제:
# 윗변의 길이가 0.87m이고 높이가 0.4m인 평행사변형의 넓이는 몇일까요?(소수 점 아래 둘 째 자리까지만 표기하시오)
# 0.31
#
# 79번 문제:
# 현주와 민준이가 고구마를 캐고 있습니다. 현주는 3kg 200g, 민준이는 2kg 100g 캤을 때, 두 사람이 캔 고구마는 몇 g인가요?
# 5300
#
# 80번 문제:
# 성현이는 월요일에 3300원, 화요일에 2590원, 목요일에 1650원, 금요일에 4230원을 저금했습니다. 월요일부터 금요일까지 저금한 금액의 평균이 3200원일 때, 수요일의 저금액은 얼마인가요?
# 30010
#
# 81번 문제:
# 어느 양꼬치집에서 원래 가격이 25000원인 빵을 사는 데 8000원을 할인받았습니다. 이 양꼬치집에서 이와 같은 할인율로 35000원짜리 양꼬치를 산다면 얼마를 할인받을 수 있는지 써 보세요.
# 0
#
# 82번 문제:
# 한 변의 길이가 12.25cm인 정사각형의 둘레는 몇 cm일까요?
# 49.00
#
# 83번 문제:
# 노트북은 760000원, 세탁기는 920000원 입니다. 노트북과 세탁기 중 어느 것이 가격이 더 비쌀까요?
#
#
# 84번 문제:
# 볼펜 356개를 한 상자에 25개씩 담아서 팔려고 합니다. 최대 몇 상자를 팔 수 있습니까?
# 14
#
# 85번 문제:
# 둘레가 360미터인 정사각형 모양의 정원의 넓이는 몇 제곱미터일까요?
# 1440
#
# 86번 문제:
# 34보다 크고 48보다 작은 수는 모두 몇 개 인가요?
# 12
#
# 87번 문제:
# 정혜는 우유 2 L 중에서 동생에게 0.66 L, 오빠에게 0.8 L 를 주고 남은 양을 모두 마셨습니다. 누가 가장 많은 양을 마셨나요?
#
#
# 88번 문제:
# 50에 어떤 수를 더하고 44을 빼야 할 것을 잘못하여 50에서 어떤 수를 뺐더니 25가 되었습니다. 바르게 계산하면 얼마가 되는지 구하세요.
# 3750
#
# 89번 문제:
# 경석이네 학교의 남학생은 675명이고 여학생은 316명입니다. 경석이네 학교의 학생은 모두 몇 명이 될까요?
# 991
#
# 90번 문제:
# 수정이는 어제 520쪽인 책 한 권의 1/13을 읽었습니다. 읽은 양은 몇 쪽인지 구하시오.
# 40
#
# 91번 문제:
# 윤희는 32cm짜리 색 테이프를 갖고 있습니다. 이 중 8cm를 사용했을 때, 남은 색 테이프의 길이는 28cm의 몇 분의 몇인지 계산해 보세요.
# -192
#
# 92번 문제:
# 도담이는 도토리를 3.46kg 주웠고 혜정이는 571g 의 9 배 만큼 주웠습니다. 도담이와 혜정이 중에서 누가 도토리를 더 많이 주웠을까요?
#
#
# 93번 문제:
# 정가가 2500원인 과자를 A 가게에서는 400원 할인해 주고, B 가게에서는 4% 할인해 준다고 합니다. 어느 가게에서 과자를 사는 것이 더 저렴할까요?
# invalid syntax (<string>, line 3)
#
# 94번 문제:
# 주어진 나눗셈 6A / 8이 나누어떨어질 때의 A 값을 구하시오.
# 0
#
# 95번 문제:
# 다음 숫자 카드 4, 5, 7, 8를 한 번씩 사용하여 세 자리 수를 만들 때, 가장 큰 수와 가장 작은 수의 차는 얼마일까요?
# 8754
#
# 96번 문제:
# 한 변의 길이가 100cm인 정팔각형과 한 변의 길이가 60cm인 정오각형의 둘레의 합을 구하시오.
# 920
#
# 97번 문제:
# 현일이네 모둠 학생들이 색종이로 종이꽃을 만들려고 합니다. 만든 종이꽃을 한 상자에 36 개씩 5 줄로 담을 수 있고, 색종이는 한 상자에 40 장씩 6 상자 있습니다. 종이꽃을 만들고 남은 색종이는 몇 장인지 계산해보세요. (단, 색종이 1 장으로 종이꽃 1 장을 만들 수 있습니다.)
# -1164
#
# 98번 문제:
# 형찬이는 줄넘기를 오전에 142회, 오후에 183회 했습니다. 형찬이는 오늘 줄넘기를 총 몇 회 했는지 구해보시오.
# 325
#
# 99번 문제:
# 3장의 숫자 카드 2,3,8 를 한 번씩만 사용하여 나눗셈 식 AB/C를 만들려고 합니다. 몫이 가장 크게 되는 나눗셈 식의 몫을 구하시오.
# 3
#
# 100번 문제:
# 숫자 카드 5, 7, 9이 있다. 3장의 수 카드를 한 번씩만 사용하여 두 자리수 A와 한자리 수 B를 만들고, A / B와 같은 나눗셈식을 만들려고 합니다. 만든 나눗셈의 몫이 가장 작을 때의 몫을 구하여 보세요.
# 6
#
# 101번 문제:
# 호중이는 한 봉지에 12개씩 들어 있는 쿠키 7봉지를 갖고 있습니다. 쿠키를 4명에게 나누어 주려고 할 때, 한 명에게 몇 개씩 나누어 줄 수 있을까요?
# 21
#
# 102번 문제:
# 세 변의 길이가 각각 21cm로 같은 삼각형이 있습니다. 이 삼각형의 세 변의 길이를 모두 더하면 몇 cm일까요?
# 63
#
# 103번 문제:
# 경무의 수학 점수는 78점입니다. 대경이의 수학 점수는 경무보다 14점 낮고, 성수의 수학 점수는 대경이보다 9점 더 높다고 합니다. 누구의 수학 점수가 가장 높을까요?
# 0
#
# 104번 문제:
# 4장의 수 카드 1, 3, 8, 9을 한 번씩 모두 사용하여 만들 수 있는 가장 큰 네 자리 수를 구하세요.
# 9831
#
# 105번 문제:
# 45의 약수 중에서 3의 배수의 합을 구하여 보세요.
# 6
#
# 106번 문제:
# 어떤 수의 배수 중 가장 작은 수부터 8번째 배수와 9번째 배수의 차는 15입니다. 어떤 수의 9번째 배수는 몇 일까요?
# 127
#
# 107번 문제:
# 한 자리 수 A, B가 두 자리 수끼리의 덧셈 식 A7 - 2B = 74 를 만족할 때, 두 수 A, B의 합을 구하세요.
# -65
#
# 108번 문제:
# 가로가 4.2m, 세로가 2.4cm인 직사각형의 넓이는 몇 m²일까요?
# 10.08
#
# 109번 문제:
# 빨간 구슬은 85개 있고, 노란 구슬은 36개 있고, 파란 구슬은 노란 구슬보다 12개 더 많이 있습니다. 빨간 구슬은 파란 구슬보다 몇 개 더 많을까요?
# 61
#
# 110번 문제:
# 교무실 앞 한쪽 벽에 가로가 8cm, 세로가 5cm인 직사각형 모양의 타일을 빈틈없이 겹치지 않게 한 줄에 12개씩 25줄 붙였습니다. 타일을 붙인 벽의 넓이는 몇 cm²일까요?
# 86352314485104768360618693069902950709683474335359918288725087348096107278452519741031278976941582209991953446470680576
#
# 111번 문제:
# 숫자 카드 3, 2, 8, 6을 한 번씩 사용하여 2개의 두 자리 수를 만들었을 때, 두 수의 곱이 가장 크게 될 때의 값을 구해보세요.
# 5166
#
# 112번 문제:
# 기차가 서울에서 강원도까지 가는 데에 2시간이 걸리고, 강원도에서 부산까지 가는 데에 3시간이 걸린다고 합니다. 서울에서 부산까지 가는 데에는 몇 시간이 걸립니까?
# 6
#
# 113번 문제:
# 효정이네 반은 남학생 24명, 여학생 25명으로 이루어져 있습니다. 안경을 쓰지 않은 학생이 28명이라면 안경을 쓴 학생은 몇 명일까요?
# -29
#
# 114번 문제:
# 윗변의 길이가 8cm, 아랫변의 길이가 13cm이고 높이가 8cm인 사다리꼴의 넓이는 몇 cm²일까요?
# 84
#
# 115번 문제:
# 들이가 4L인 물병을 상우는 약 3L 200mL, 서형이는 약 3L 750mL로 어림하였습니다. 실제 들이에 더 가깝게 어림한 사람은 누구일까요?
#
#
# 116번 문제:
# 둘레가 25.7cm인 정오각형이 있습니다. 이 정오각형의 한 변의 길이는 몇 cm인지 구해보세요.
# 5.14
#
# 117번 문제:
# 직사각형의 가로의 길이가 10/13m, 세로의 길이가 2/7m일 때, 가로의 길이와 세로의 길이의 차를 구해 소수로 나타내세요.
# 0.48
#
# 118번 문제:
# 퀴즈 대회에 참가한 학생은 98명이고 이 중에서 22명이 본선에 진출하였습니다. 본선에 진출한 학생 수의 대회에 참가한 전체 학생 수에 대한 비율을 소수로 나타내보세요.
# 2156.00
#
# 119번 문제:
# 열차에 621명이 타고 있었는데 광주역에서 102명이 내리고 158명이 탔습니다. 현재 열차에 타고 있는 사람은 몇 명인가요?
# 677
#
# 120번 문제:
# 넓이가 150cm²인 삼각형의 높이가 15cm일 때, 밑변의 길이는 몇 cm 인가요?
# 183
#
# 121번 문제:
# 어떤 수를 4.2로 나누어야 할 것을 잘못하여 곱했더니 22.46이 되었습니다. 바르게 계산한 값은 얼마인지 답을 구해 보시오.
# 5.35
#
# 122번 문제:
# 희진이네 학교의 2학년 남학생은 239명, 여학생은 225명입니다. 1학년 학생 수는 2학년 학생 수보다 13명 더 적을 때, 1학년 학생은 총 몇 명인지 구해보세요.
# 464
#
# 123번 문제:
# 들이가 2300 mL 인 물통과 들이가 2400 mL 인 주스 병에 물을 가득 채운 후 양동이에 옮겨 담았더니 물통이 가득 찼습니다. 들이가 4500 mL 인 주전자와 물통 중에서 어느 것의 들이가 더 클까요?
#
#
# 124번 문제:
# 정팔각형의 한 변의 길이가 12.5cm일 때, 둘레의 길이를 구하세요.
# 62.50
#
# 125번 문제:
# 멀리 원반 던지기 기록을 재어 보니 정규는 16.4m, 채영이는 14.5m, 호연이는 19.3m, 우식이는 13.9m였습니다. 가장 멀리 던진 사람은 누구일까요?
#
#
# 126번 문제:
# 네 변의 길이의 합이 88cm인 정사각형의 한 변의 길이는 몇 cm인가요?
# 22
#
# 127번 문제:
# 한 변의 길이가 50cm인 정사각형을 가로는 15% 늘이고, 세로는 20% 줄여서 직사각형을 만들었습니다. 정사각형의 넓이에 대한 직사각형의 넓이의 비율을 소수점 둘 째 자리까지 나타내보시오.
# 0.00
#
# 128번 문제:
# 철사를 35 도막으로 자르려고 합니다. 철사를 한 번 자 르는 데 7 초가 걸린다면, 쉬지 않고 40 도막으로 자르 는 데 모두 몇 초가 걸리겠습니까?
# 7
#
# 129번 문제:
# 한 변의 길이가 7cm인 정오각형의 둘레는 몇 cm인가요?
# 35
#
# 130번 문제:
# 세로가 가로의 3배인 직사각형이 있습니다. 이 직사각형의 가로가 5cm 일 때, 네 변의 길이의 합은 몇 cm 인가요?
# 30
#
# 131번 문제:
# 경빈이네 학교 2학년은 6개 반입니다. 각 반의 학생 수는 28명입니다. 경빈이네 학교 2학년 학생 수는 모두 몇 명입니까?
# 168
#
# 132번 문제:
# 학생들이 키가 작은 순서대로 줄을 서있습니다. 연지의 키는 네 번째로 작고, 수정이의 키는 여섯 번째로 작습니다. 준희의 키는 연지보다 크고 수정이보다 작다면 준희는 몇 번째에 서 있나요?
# 10
#
# 133번 문제:
# 한 변이 34cm인 정사각형 안에 그릴 수 있는 가장 큰 원의 반지름은 몇 cm인가요?
# 136
#
# 134번 문제:
# 184÷(4×2)를 계산한 값은 얼마일까요?
# 370
#
# 135번 문제:
# 둘레가 32cm인 정사각형 안에 그릴 수 있는 가장 큰 원의 넓이는 몇 cm²일까요? (원주율: 3.1)
# 4
#
# 136번 문제:
# 넓이가 196m²인 정사각형이 있습니다. 이 정사각형의 둘레는 몇 m일까요?
# 56
#
# 137번 문제:
# 사과의 무게는 100원짜리 동전 37개의 무게와 같고, 복숭아의 무게는 100원짜리 동전 42개의 무게와 같습니다. 어떤 것이 더 가벼울 지 찾아보세요.
# -3758
#
# 138번 문제:
# 뮤지컬 상영 시간은 2+3/5시간이고 뮤지컬 상영관에서 집에 가는 데 걸리는 시간은 2+2/8시간입니다. 지금 뮤지컬이 시작한다면 뮤지컬을  보고 집에 가는 데까지 걸리는 시간은 모두 몇 시간이 될까요?
# 1.70
#
# 139번 문제:
# 식초 45.6L를 한 병에 2.4L씩 담으려고 합니다. 필요한 병은 모두 몇 개 일까요?
# 19
#
# 140번 문제:
# 면이 9개인 각기둥의 꼭짓점은 몇 개인가요?
# 18
#
# 141번 문제:
# 어떤 직육면체의 가로의 길이가 6cm, 세로의 길이가 4cm, 높이가 8cm입니다. 이 직육면체의 전체 둘레는 얼마일까요?
# 40
#
# 142번 문제:
# 딸기 25개 중에서 현서는 전체의 3/5을, 희진이는 전체의 2/5를 먹었습니다. 딸기를 더 많이 먹은 사람은 몇 개 더 많이 먹었을까요?
#
#
# 143번 문제:
# 주희는 종이접기를 하고 있습니다. 전체 색종이의 5/12을 사용하여 학을 만들고, 전체 색종이의 1/4을 사용하여 꽃을 만들었습니다. 남은 색종이는 전체의 얼마인지 소수로 나타내세요.
# 0.17
#
# 144번 문제:
# 학 한 마리를 만드는 데 종이 테이프 37cm가 필요합니다. 종이 테이프 240cm로 학을 최대 몇 마리 만들 수 있는지 구하시오.
# 18.50
#
# 145번 문제:
# 3.46, 5.78, 6.12중 가장 큰 수와 가장 작은 수의 합을 구하여 보세요.
# 9.58
#
# 146번 문제:
# 포도 주스 24.48L를 병 8개에 똑같이 나누어 담으려고 합니다. 병 한 개에 담아야 할 포도 주스는 몇 L인지 구해보세요.
# 3
#
# 147번 문제:
# A는 60 * 3의 값이고, B는 95 * 2의 값일 때 A와 B 중 더 큰 수를 찾아보세요.
# 'int' object is not iterable
#
# 148번 문제:
# 나무인형인 밤송이의 코의 길이는 3cm입니다.밤송이가 굴러다니면  코의 길이가 처음보다 2배만큼 늘어난다고 합니다. 밤송이가 굴러다니는걸  한 번 했다면 코의 길이는 몇 cm가 되었을까요?
# 6
#
# 149번 문제:
# 길이가 21.98cm인 끈을 사용해 만들 수 있는 가장 큰 원의 반지름은 몇 cm인가요? 원주율은 3.14로 계산합니다.
# 6.97
#
# 150번 문제:
# 감자 56개를 상자 2개에 똑같이 나누어 넣으려고 합니다. 한 상자에 넣을 수 있는 감자는 몇 개 일지 계산해보시오.
# 28
#
# 151번 문제:
# 소설책 63권을 책꽂이 한 칸에 9 권씩 꽂으려고 합니다. 책꽂이는 몇 칸 필요할까요?
# 7
#
# 152번 문제:
# 한 시간에 45바퀴를 도는 물레방아가 있습니다. 물레방아가 8시간 동안 도는 횟수는 몇 바퀴일까요?
# 360
#
# 153번 문제:
# 사각형이 6개일 때, 변의 개수는 몇 개일까요?
# 12
#
# 154번 문제:
# 상자 한 개를 포장하는 데 리본 1.8m가 필요합니다. 리본이 총 15.24m 있을 때, 최대 몇 개의 상자를 포장할 수 있을까요?
# 0
#
# 155번 문제:
# 지름이 90cm인 원 모양의 바퀴 자를 사용하여 책상의 길이를 측정하는데, 책상의 길이가 1395cm일 때 바퀴가 몇 바퀴 돌았는지 구해 보세요. 원주율은 3.1로 계산합니다.
# 48.05
#
# 156번 문제:
# 진분수 A/35가 있다. 이 진분수를 약분하면 1/7가 된다고 할 때, A를 구하여 보세요.
# 245
#
# 157번 문제:
# 길이가 64 cm 인 철사를 모두 사용하여 직사각형 한 개를 만드려고 합니다. 직사각형의 짧은 변을 12 cm로 하려면 긴 변은 몇 cm 로 해야 할까요?
# 5
#
# 158번 문제:
# 반지름이 20cm인 원 A, 지름이 50cm인 원 B가 있습니다. 두 원의 넓이의 차를 구하시오. 원주율은 3.1로 계산합니다.
# 3100.00
#
# 159번 문제:
# 16, 12, 86 중에서 가장 큰 수를 가장 작은 수로 나눈 몫을 구해 보세요.
# 7
#
# 160번 문제:
# 850cm은 Am Bcm 입니다. A와 B를 더한 값을 구하시오.
# 1600
#
# 161번 문제:
# 382은 A보다 210이 큰 수입니다. 74은 46보다 B 큰 수입니다. A와 B의 곱을 구하시오.
# 106
#
# 162번 문제:
# 수조에 물을 가득 채우려면 A, B, C 컵으로 각각 16번, 18번, 19번 부어야 합니다. A, B, C 컵 중에서 컵의 크기가 가장 작은 것은 무엇인가요?
# -54
#
# 163번 문제:
# 은행에 예금한 돈 385200원을 10만 원권 수표로 찾으려고 합니다. 수표를 몇 장까지 찾을 수 있을까요?
# 385520
#
# 164번 문제:
# 한 장의 길이가 3m인 도화지 23장을 일렬로 이어 붙였습니다. 이어 붙인 도화지의 총 길이는 몇 m일까요?
# 69
#
# 165번 문제:
# 400보다 크고 500보다 작은 36와 52의 최소공배수의 배수를 구하세요.
# 0
#
# 166번 문제:
# 3장의 숫자 카드 2,3,4 를 한 번씩만 사용하여 나눗셈식 AB/C를 만들려고 합니다. 몫이 가장 크게 되는 나눗셈 식의 몫을 구하시오.
# 1
#
# 167번 문제:
# 어떤 수의 3/5가 50 입니다. 어떤 수의 4/10는 얼마일까요?
# 33
#
# 168번 문제:
# 3장의 수 카드 4, 5, 8 중 2장을 뽑아 한 번씩만 사용하여 가장 큰 소수 한 자리 수와 가장 작은 소수 한 자리 수를 각각 만들었습니다. 만든 두 소수의 곱은 얼마인지 구해 보세요.
# invalid literal for int() with base 10: ''
#
# 169번 문제:
# 한 변의 길이가 7cm인 평행사변형의 둘레가 46cm일 때 다른 한 변의 길이는 몇 cm일까요?
# 322
#
# 170번 문제:
# 28과 35를 곱한 값은 얼마입니까?
# 980
#
# 171번 문제:
# 명준이네 반은 남학생이 16명, 여학생이 19명입니다. 명준이네 반에서 축구를 좋아하는 학생이 10명일 때 축구를 좋아하지 않는 학생은 몇 명인지 구하세요.
# -174
#
# 172번 문제:
# 100은 A보다 60 큰 수입니다. 100은 20보다 B 큰 수입니다. A와 B를 더한 값을 구해보세요.
# 60
#
# 173번 문제:
# 수 카드 5, 2, 7, 9이 있다. 4장의 수 카드를 모두 한 번씩 사용하여 만들 수 있는 가장 큰 두 자리 수와 가장 작은 두 자리 수의 합은 얼마인지 계산해보세요.
# 122
#
# 174번 문제:
# 수 68, 54, 34 중에서 2개를 골라 곱한 값이 2312이 될 때, 두 수 중 더 작은 값은?
# -2
#
# 175번 문제:
# 민석이는 수학 숙제를 59 분 동안 하였고, 사회 숙제를 200/3 분 동안 하였습니다. 민석이가 더 오래 한 숙제는 무엇인가요?
#
#
# 176번 문제:
# 40 보다 크고 90 보다 작은 두 자리 수 중에서 6로 나누어떨어지는 수는 모두 몇 개 일까요?
# must be str, not int
#
# 177번 문제:
# 가로가 22cm이고 세로는 가로보다 4cm 더 긴 직사각형이 있습니다. 이 직사각형의 둘레는 몇 cm일까요?
# 52
#
# 178번 문제:
# 윤택이는 외할아버지 댁에 가려고 합니다. 외할아버지 댁에 가능 방법은 다음과 같은 두 가지 방법이 있습니다. 방법 A는 기차를 4/9시간 동안 타고 1/6시간을 걷습니다. 방법 B는 고속버스를 4/6시간 동안 타고 1/4시간을 걷습니다. A와 B중에서 어느 방법이 더 빨리 갈 수 있을까요?
#
#
# 179번 문제:
# 한 변이 54cm인 정사각형 안에 그릴 수 있는 가장 큰 원의 반지름은 몇 cm인지 구해보세요.
# 216
#
# 180번 문제:
# 어떤 수는 15으로 나누어도 2이 남고, 34로 나누어도 1이 남습니다. 어떤 수가 될 수 있는 수 중에서 가장 작은 수를 구하여 보세요.
# 5
#
# 181번 문제:
# 어느 전시회의 학생 입장료는 한 명당 6500원입니다. 학생 8명이 입장하려면 총 얼마를 내야할까요?
# 52000
#
# 182번 문제:
# 가로가 36cm, 세로가 10cm인 직사각형에서 긴 변의 길이와 짧은 변의 길이의 차를 구해보세요.
# 26
#
# 183번 문제:
# 생크림빵 1개의 값은 1400원이고, 단팥빵 1개의 값은 생크림빵 1개 값의 절반보다 150 원이 비싸다고 합니다. 생크림빵 8개와 단팥빵 5개를 사면 얼마를 내야할까요?
# 209960
#
# 184번 문제:
# 화단 주변에 한 변이 5m인 정팔각형 모양의 울타리를 치려고 합니다. 울타리는 총 몇 m인가요?
# 40
#
# 185번 문제:
# 두 자리 수 B가 있습니다. 다음 식 2015＜90× B에서 가장 작은 B는 얼마인지 답을 구하세요.
# name 'b' is not defined
#
# 186번 문제:
# 도영이는 피자를 똑같이 16조각으로 나누어 4조각을 먹었습니다. 기수는 같은 크기의 피자를 똑같이 19조각으로 나누어 6조각을 먹었습니다. 도영이와 기수 중 더 적은 피자를 먹은 사람은 누구인가요?
#
#
# 187번 문제:
# 두 자리 수 A4와 2을 곱하면 두 자리 수 6B가 됩니다. A와 B의 합을 구하시오.
# 14
#
# 188번 문제:
# 0에서 13까지의 숫자 중에서 8개를 골라 한 번씩 사용하여 여덟자리 수를 만들 때, 만의 자리의 숫자가 5인 가장 큰 수를 만들어 보세요.
# 0
#
# 189번 문제:
# 동물병원에서 간식을  4개에을 1250원에 팔고 있습니다. 간식을 36개 사는 데 필요한 돈은 얼마인지 구하여 보세요.
# 138
#
# 190번 문제:
# 어느 영화관의 평일 영화 관람료는 12000원입니다. 주말 영화 관람료는 평일 영화 관람료의 3/2이라고 합니다. 주말에 4명이 영화를 보려면 총 얼마를 내야합니까?
# 4500
#
# 191번 문제:
# 원 A의 지름은 88cm이고 원 B의 지름은 원 A의 반지름과 같다고 할 때, 원 B의 반지름은 몇 cm입니까?
# 0
#
# 192번 문제:
# 한 변의 길이가 16cm인 평행사변형과 한 변의 길이가 6cm인 정팔각형의 둘레가 같습니다. 이 평행사변형의 다른 한 변의 길이를 구하세요.
# 116
#
# 193번 문제:
# 8의 배수도 되고 16의 배수도 되는 수 중에서 가장 큰 세 자리 수는 얼마인가요?
# 128
#
# 194번 문제:
# 두발자전거와 세발자전거의 바퀴 수를 세었더니 모두 52개였습니다. 두발자전거가 21대 있다면 세발자전거는 몇 대 있나요?
# 31
#
# 195번 문제:
# 다혜는 선물을 포장하는 데 청록색 테이프 15 cm 8 mm 와 하늘색 테이프 245 mm 를 사용하였습니다. 다혜가 사용한 색 테이프는 모두 몇 mm 일까요?
# 365
#
# 196번 문제:
# A, B는 두 자리 수끼리의 덧셈 식 A3 + 1B = 95 를 만족하는 한 자리 수입니다. 두 수 A,B의 합은 얼마일까요?
# 98
#
# 197번 문제:
# 서로 다른 한 자리 수 A, B가 있습니다. 두 자리 수끼리의 뺄셈식 A5-3B=51에서 A와 B의 합을 구하시오.
# -26
#
# 198번 문제:
# 1부터 150까지의 수 중에서 4로도 나누어떨어지고 8로도 나누어떨어지는 수는 모두 몇 개 인가요?
# 0
#
# 199번 문제:
# 기름32.7L를 병 5개에 똑같이 나누어 담으려고 합니다. 병 한 개에 담아야 할 기름은 몇 L가 될가요?
# 6
#
# 200번 문제:
# 2, 5, 6, 12, 15 중에서 46/64을 약분하려고 할 때 분모와 분자를 나눌 수 없는 수의 개수를 구해 보세요.
# 0
#
# 201번 문제:
# 삼각형의 두 각의 크기가 각각 45°, 100° 일 때 나머지 한 각의 크기를 구해 보시오.
# 35
#
# 202번 문제:
# 7, 6, 1이 있습니다. 서로 다른 두 숫자를 뽑아 만들 수 있는 두 자리 수 중에서 가장 작은 수를 구해보세요.
# 167
#
# 203번 문제:
# 숫자 카드 7, 4, 2이 있다. 3장의 수 카드 중에서 2장을 뽑아 두 수의 곱을 구하려고 합니다. 가장 작은 곱은 얼마가 될까요?
# 8
#
# 204번 문제:
# 가로의 길이가 22cm이고 세로의 길이가 Acm인 직사각형이 있습니다. 이 직사각형의 둘레가 86cm일 때 A를 구하세요.
# 5
#
# 205번 문제:
# 육각뿔의 면의 수와 모서리 수의 합은 몇 개인가요?
# 30
#
# 206번 문제:
# 철수는 부모님과 함께 수산 시장을 갔습니다. 갈치 한 마리의 가격이 3300원입니다. 갈치 5마리의 가격은 얼마일까요?
# 16500
#
# 207번 문제:
# 영빈이는 사탕을 한 사람에게 5개씩 나누어 주려고 합니다. 박하 사탕은 82개, 오렌지 맛 사탕은 56개 있을 때 최대 몇 명에게 나누어 줄 수 있을까요?
# 56
#
# 208번 문제:
# 5보다 크고 13보다 작은 수는 모두 몇 개 인가요??
# 7
#
# 209번 문제:
# 모서리가 6개인 각뿔의 밑면의 꼭짓점 수를 쓰세요.
# 13
#
# 210번 문제:
# 민숙이네 텃밭은 세로 6.3m인 직사각형 모양입니다. 가로가 세로의 5.6배일 때 민숙이네 텃밭의 넓이는 몇 제곱미터인지 구하세요.
# 35.28
#
# 211번 문제:
# 달수는 1시간 25분 동안 책을 읽었습니다. 달수가 책을 읽은 시간은 몇 분인지 구해 보세요.
# 1
#
# 212번 문제:
# 재연이는 238쪽짜리 동화책을 매일 같은 쪽수씩 7일동안 읽으려고 합니다. 하루에 몇 쪽씩 읽어야 합니까?
# 1666
#
# 213번 문제:
# 윗접시저울의 왼쪽 접시에 무게가 600g 인 수박을 올려놓고 오른쪽 접시에 한 개당 100g인 사과 4개와 한 개당 50g인 귤 2개를 올려놓았더니 윗접시저울이 왼쪽으로 기울었습니다. 윗접시저울이 수평이 되도록 하려면 오른쪽 접시에 귤을 몇 개 더 올려야 할까요?
# -4600
#
# 214번 문제:
# 꽃병에 코스모스가 31송이, 튤립이 18송이 있습니다. 꽃은 모두 몇 송이 있을까요?
# 558
#
# 215번 문제:
# 문구점에서 노트 6권을 1500원에 팔고 있습니다. 공책을 24권 사려면 얼마를 내야할까요?
# 36000
#
# 216번 문제:
# 세은이가 키우는 고양이는 5월에 몸무게가 3.2kg이었습니다. 6월에는 5월보다 몸무게가 0.3배만큼 늘어났다고 할 때, 세은이가 키우는 고양이의 몸무게는 6월에 몇 kg일까요?
# 0.96
#
# 217번 문제:
# A, B는 서로 다른 한 자리 수입니다. A, B가 두 자리 수끼리의 덧셈 식 A3 - 2B = 66 를 만족할 때, 두 수 A, B의 곱을 구하세요.
# 495
#
# 218번 문제:
# 한 자리 수 A, B가 두 자리 수끼리의 덧셈 식 3A + B8 = 54 를 만족할 때, 두 수 A, B의 합을 구하세요.
# 182
#
# 219번 문제:
# 넓이가 168cm², 밑변의 길이가 14cm, 윗변의 길이가 7cm인 사다리꼴이 있습니다. 높이는 몇 cm일까요?
# 16
#
# 220번 문제:
# 어떤 수에 15를 곱해야 할 것을 잘못하여 11를 더하였더니 32이 되었습니다. 바르게 계산한 값은 얼마입니까?
# 315
#
# 221번 문제:
# 원 A의 지름은 84cm이고 원 B의 지름은 원 A의 반지름과 같다고 합니다. 두 원의 반지름의 차를 구해보세요.
# 21
#
# 222번 문제:
# 두 자리 수 A7에 5를 곱한 값은 445입니다. A안에 들어갈 알맞은 수를 구해보세요.
# 58
#
# 223번 문제:
# 24개의 모과를 한 봉지에 3개씩 담고 그 중 한 봉지를 친구에게 주었을 때 남은 모과의 수는 몇 개일까?
# 16
#
# 224번 문제:
# 연주는 체험 활동을 가서 가로가 6m, 세로가 3m인 직사각형 모양의 벽에 페인트를 칠했습니다. 연주가 페인트를 칠한 벽의 넓이는 몇 m²일까요?
# 18
#
# 225번 문제:
# 8235를 32로 나눈 나머지는 얼마입니까?
# 8203
#
# 226번 문제:
# 정사각형의 둘레는 28cm 입니다. 한 변의 길이는 몇 cm입니까?
# 7
#
# 227번 문제:
# 한 변의 길이가 9cm인 마름모의 둘레를 구해보세요.
# 36
#
# 228번 문제:
# 5분 동안 5.85km를 가는 자동차와 10분 동안 11.24km를 가는 오토바이가 있습니다. 자동차와 오토바이가 같은 곳에서 반대 방향으로 동시에 출발한다면 1시간 후에 자동차와 오토바이는 얼마만큼 멀어질까요? (단, 자동차와 오토바이는 각각 일정한 빠르기로 갑니다.)
# 59.50
#
# 229번 문제:
# 숫자 카드 4, 1, 5, 8, 6 중에서 2장을 골라 한 번씩만 사용하여 소수 한 자리 수를 만들 때, 6보다 큰 소수는 모두 몇 개 만들 수 있을까요?
# '>=' not supported between instances of 'int' and 'list'
#
# 230번 문제:
# 한 변의 길이가 4cm인 정삼각형이 2개 있을 때, 두 삼각형의 둘레의 합은 몇 cm일까요?
# 12
#
# 231번 문제:
# 둘레가 132cm인 정십이각형이 있습니다. 이 정십이각형의 한 변은 몇 cm일까요?
# 13
#
# 232번 문제:
# 한 사람당 케이크 한 판의 1/5씩 나누어 주려고 합니다. 8명에게 나누어 주려면 케이크는 몇 판 사야할까요?
# 0
#
# 233번 문제:
# 어떤 수를 2.6로 나누어야 할 것을 잘못하여 곱하였더니 520이 되었습니다. 바르게 계산하면 얼마입니까?
# 200
#
# 234번 문제:
# 준수네 농장에서 매실 295kg을 수확했습니다. 이 매실을 한 자루에 20kg씩 담는다면 총 몇 자루에 담을 수 있을까요?
# 14
#
# 235번 문제:
# 꼭짓점의 수와 모서리의 수의 합이 55개인 각기둥의 면은 모두 몇 개일까요?
# 36
#
# 236번 문제:
# 민희의 머리카락은 하루에 0.3 mm씩 자랍니다. 민희의 머리카락 길이가 오늘 28.45 cm일 때, 23일이 지나면 몇 cm일까요?
# -654.05
#
# 237번 문제:
# 숫자 카드 9, 7, 3이 있다. 수 카드 3장 중에서 2장을 골라 두 자리 수를 만들려고 합니다. 만들 수 있는 가장 큰 수와 가장 작은 수를 더한 값은 몇 일까요?
# sequence item 0: expected str instance, int found
#
# 238번 문제:
# 설탕물 양에 대한 설탕 양의 비율이 25%인 설탕물을 만들려고 합니다. 설탕을 50g 넣었을 때 물은 몇 g을 넣어야 하나요?
# 0.50
#
# 239번 문제:
# 수박 한 통을 동일한 크기로 9조각으로 나누었습니다. 5명이 한 조각씩 먹었다면 남은 수박의 양은 1/9이 몇 개일까요?
# 44
#
# 240번 문제:
# 4장의 숫자 카드 5, 6, 2, 9 가 있습니다. 이 카드 중에서 2장만 사용하여 가장 큰 분수를 만들었을 때, 분자와 분모를 더한 값을 구해보세요.
# 18
#
# 241번 문제:
# 어느 문구점에서는 종이 1장을 120원에 사 와서 220원에 판매하고 있습니다. 이 문구점에서 종이 40장을 팔면 이익이 얼마일까요?
# -26360
#
# 242번 문제:
# 1060, 1207, 1145, 1021이 있습니다. 가장 작은 수는 무엇일가요?
# -1381855
#
# 243번 문제:
# 2000m 달리기에서 육상 선수가 8.3분 동안에 완주하였다면 이 선수는 1분 동안 몇 m를 달린 것인가요?
# 8.30
#
# 244번 문제:
# 현정이는 하루 24시간 중 0.4 만큼을 학교에서 생활을 하고 그 중 0.6만큼은 공부를 합니다. 현정이는 학교에서 하루에 몇 시간을 공부할까요?
# 10.20
#
# 245번 문제:
# 빵 한 개를 만드는 데 우유가 0.24L 필요합니다. 우유 5.2L로 쿠키를 몇 개 만들 수 있는지 구하세요.
# 21
#
# 246번 문제:
# 한 변의 길이가 30.66m인 정사각형의 둘레는 몇 m입니까?
# 122.64
#
# 247번 문제:
# 6의 배수를 가장 작은 수부터 차례로 쓸 때 19번째의 수를 구해 보시오.
# 114
#
# 248번 문제:
# 어떤 수에서 333을 빼야 할 것을 잘못하여 33을 뺐더니 641이 되었습니다. 바르게 계산 하면 얼마인가요?
# 671
#
# 249번 문제:
# 어떤 수에 8을 곱해야 할 것을 잘못하여 8을 더했더니 96이 되었습니다. 바르게 계산하면 얼마입니까?
# 80
#
# 250번 문제:
# 한 변의 길이가 33.1cm인 정사각형의 둘레는 몇 cm인가요?
# 132.40
#
# 251번 문제:
# 한변의 길이가 5cm인 정사각형의 둘레를 구하시오.
# 20
#
# 252번 문제:
# 정미네 반 학생은 32명입니다. 자동차 1대 당 7명까지 탈 수 있을 때, 정미네 반 학생을 모두 태우려면 자동차는 최소 몇 대 필요한가요?
# 224
#
# 253번 문제:
# 30, 70의 최대공약수를 구하여 보세요.
# 10
#
# 254번 문제:
# 한 변의 길이가 11cm인 정칠각형의 둘레는 몇 cm일까요?
# 77
#
# 255번 문제:
# 모든 모서리의 길이가 같은 오각뿔이 있습니다. 모서리의 길이의 합이 75.46cm일 때 한 모서리의 길이는 몇 cm인지 구해보시오.
# 0.50
#
# 256번 문제:
# 윗변의 길이가 26cm, 아랫변의 길이가 40cm인 사다리꼴이 있습니다. 이 사다리꼴의 넓이가 396cm²일 때 높이는 몇 cm일까요?
# 0
#
# 257번 문제:
# 커피 25.2L를 한 병에 4.2L씩 담으려고 합니다. 필요한 병은 모두 몇 개인지 구해보세요.
# 6
#
# 258번 문제:
# 명훈이는 한 권에 1250원인 공책을 6권 사려고 합니다. 명훈이가 내야하는 금액은 얼마일까요?
# 7500
#
# 259번 문제:
# 가로의 길이가 21cm, 세로의 길이가 15cm인 직사각형의 둘레를 구해보세요.
# 72
#
# 260번 문제:
# 다음 식 96/A=12 , 144/A=B 이 있습니다. 이를 만족하는 A와 B의 합을 구하시오.
# 84
#
# 261번 문제:
# 한 모서리의 길이가 10cm인 정육면체의 모든 모서리의 길이의 합은 몇 cm입니까?
# 60
#
# 262번 문제:
# 한 변의 길이가 24cm인 정삼각형이 있습니다. 이 정삼각형과 둘레가 같은 정사각형의 한 변의 길이는 몇 cm인지 구해보고 소수점 아래 둘째자리까지 표기하세요.
# 18
#
# 263번 문제:
# 정육면체의 면, 모서리, 꼭짓점의 수의 합을 구하시오.
# 42
#
# 264번 문제:
# 수 3, 4, 8, 7 중에서 3개를 골라 두 자리 수 AB와 한 자리 수 C를 곱할 때, 곱이 가장 큰 경우의 값을 구해 보세요.
# 6142
#
# 265번 문제:
# 길이가 58 cm인 철사를 사용해 가장 큰 정사각형을 만들려고 합니다. 한 변의 길이를 몇 cm로 하면 될까요?
# 14
#
# 266번 문제:
# 가로가 15cm, 세로가 7cm인 직사각형의 넓이를 구하시오.
# 105
#
# 267번 문제:
# 수학 시험에서 소연이는 9등을 했고, 승희는 11등을 했습니다. 승준이는 승희보다 못했지만 소연이보다는 잘했습니다. 승준이는 몇 등입니까?
# 2
#
# 268번 문제:
# 어떤 수에서 0.45 를 빼야 할 것을 잘못하여 더했더니 3.22 이 되었습니다. 바르게 계산하면 얼마가 나올까요?
# 2.77
#
# 269번 문제:
# 어떤 수에 32을 곱해야 할 것을 잘못하여 뺐더니 132가 되었습니다. 바르게 계산한 결과를 구하세요.
# 5248
#
# 270번 문제:
# 네 변의 길이의 합이 56cm인 정사각형의 한 변의 길이는 몇 cm일까요?
# 14
#
# 271번 문제:
# 민주네 초등학교에서는 비 오는 날 우산을 가져오지 못한 학생들에게 빌려줄 수 있는 우산을 구입하였습니다. 우산 120개 중에서 55개를 학생들이 빌려갔다면, 빌려가지 않은 우산은 몇 개인가요?
# 65
#
# 272번 문제:
# 30부터 80까지의 수 중에서 4의 배수이면서 6의 배수인 수는 모두 몇 개 일까요?
# 0
#
# 273번 문제:
# 윗접시저울의 왼쪽 접시에 무게가 671g 인 소설책 한 권과 450g 인 과학책 한 권을 올려놓고 오른쪽 접시에 38g 짜리 분동 18개를 올려놓았더니 윗접시저울이 왼 쪽으로 기울었습니다. 윗접시저울이 수평이 되려면 1g 짜리 분동이 몇 개 필요한지 구해 보세요.
# -305
#
# 274번 문제:
# 한 자리 수 A, B가 두 자리 수끼리의 덧셈 식 5A + B2 = 78 를 만족할 때, 두 수 A, B의 합을 구하세요.
# 20
#
# 275번 문제:
# 한 시간에 오토바이를 15대씩 만드는 공장이 있습니다. 이 공장에서 21시간 동안 만들 수 있는 오토바이는 모두 몇 대가 될까요?
# 315
#
# 276번 문제:
# 어떤 두 수의 최대공약수가 64일 때 두 수의 공약수는 모두 몇 개일까요?
# 7
#
# 277번 문제:
# 약분하면 3/4가 되는 분수 중에서 분모와 분자의 차가 12일 때, 분모와 분자의 합을 구해 보세요.
# -11.25
#
# 278번 문제:
# 할머니께서 쪽파를 35개 사 오셨습니다. 이 쪽파을 일주일 동안 매일 같은 수만큼 먹으려고 합니다. 하루에 몇 개씩 먹어야 합니까?
# 5
#
# 279번 문제:
# 어떤 수에서 6를뺀 후 3을 더해야 할 것을 잘못하여 어떤 수에 5를 더한 후 4을 빼었더니 9이 되었습니다. 바르게 계산하면 얼마일까요?
# 42
#
# 280번 문제:
# 4 장의 수 카드 3, 8, 7, 4 중 3 장을 골라 한 번씩만 사용하여 만들 수 있는 가장 큰 세 자리 수와 남은 수 카드의 수의 곱은 얼마일까요?
# 303278
#
# 281번 문제:
# 883.22보다 12.86 작은 값을 구해보세요.
# 860.36
#
# 282번 문제:
# 혜주는 우유를 한 번에 320mL씩 하루 4번 마십니다. 5일 동안 마신 우유의 양은 모두 몇 mL일까요?
# 1285
